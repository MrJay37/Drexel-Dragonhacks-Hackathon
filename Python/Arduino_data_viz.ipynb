# %%
from google.colab import drive
drive.mount('/content/drive', force_remount= True)
import pandas as pd
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
DATADIR = "/content/drive/My Drive/"
df3 = pd.read_csv('/content/drive/My Drive/Arduino Data.csv')

# %%
plt.subplot(2,2,1)
df3.Humidity.plot(color='g',lw=1.3)
plt.title('Humidity')
plt.subplot(2,2,2)
df3.Temperature.plot(color='r',lw=1.3)
plt.title('Temperature')
plt.subplot(2,2,3)
df3.CarbonMonoxide.plot(color='b',lw=1.3)
plt.title('Carbon Monoxide')
# Out:
# Text(0.5, 1.0, 'Carbon Monoxide')
