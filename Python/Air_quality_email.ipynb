# %%
import smtplib, ssl
port = 465  # For SSL
smtp_server = "smtp.gmail.com"
sender_email = "dragonhacks4ducks@gmail.com"  # Enter your address
receiver_email = "raghavdaga3001@gmail.com"  # Enter receiver address
password = "Drag@4Ducks\n"
message = """\
Subject: Bad Air Quality!!!

The air quality in your kitchen has reached a poor level. Please take immediate action and check if everything is alright. Thank you"""

context = ssl.create_default_context()
with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, message)
